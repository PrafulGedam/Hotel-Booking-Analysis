# %% [markdown]
# ## <b> Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# ## <b>This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. </b>
#
# ## <b> Explore and analyze the data to discover important factors that govern the bookings. </b>

# %% [markdown]
# **`importing libaries `**
#
# ---

# %%
# Importing all import python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Hotel booking/Hotel Bookings.csv')

# %% [markdown]
# **Loading data set**

# %% [markdown]
# ##Data exploration

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
# printing the shape of the dataframe
df.shape
# Out:
# (119390, 32)

# %%
# Viewing the names of columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# information of the column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# view statistical summery of dataset
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
# making a copy of dataset
df1=df.copy()

# %%
# Checking datatypes of columns
df1.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %% [markdown]
# **Lets find out if any of the coloumns have any null or missing values**

# %%
df.isna().sum().sort_values(ascending=False) #checking the null values in columns
# Out:
# company                           112593
# agent                              16340
# country                              488
# children                               4
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# hotel                                  0
# previous_cancellations                 0
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# previous_bookings_not_canceled         0
# is_repeated_guest                      0
# is_canceled                            0
# distribution_channel                   0
# market_segment                         0
# meal                                   0
# babies                                 0
# ...

# %%
# checking for null values
null = pd.DataFrame({'Null Values' : df.isnull().sum(), 'Percentage Null Values' : (df.isnull().sum()) / (df.shape[0]) * (100)})
null
# Out:
#                                 Null Values  Percentage Null Values
# hotel                                     0                0.000000
# is_canceled                               0                0.000000
# lead_time                                 0                0.000000
# arrival_date_year                         0                0.000000
# arrival_date_month                        0                0.000000
# arrival_date_week_number                  0                0.000000
# arrival_date_day_of_month                 0                0.000000
# stays_in_weekend_nights                   0                0.000000
# stays_in_week_nights                      0                0.000000
# adults                                    0                0.000000
# children                                  4                0.003350
# babies                                    0                0.000000
# meal                                      0                0.000000
# ...

# %%
# check unique value 
df.nunique()
# Out:
# hotel                                2
# is_canceled                          2
# lead_time                          479
# arrival_date_year                    3
# arrival_date_month                  12
# arrival_date_week_number            53
# arrival_date_day_of_month           31
# stays_in_weekend_nights             17
# stays_in_week_nights                35
# adults                              14
# children                             5
# babies                               5
# meal                                 5
# country                            177
# market_segment                       8
# distribution_channel                 5
# is_repeated_guest                    2
# previous_cancellations              15
# previous_bookings_not_canceled      73
# reserved_room_type                  10
# assigned_room_type                  12
# booking_changes                     21
# deposit_type                         3
# agent                              333
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
categorical_cols=list(set(df.drop(columns=['reservation_status_date','country','arrival_date_month']).columns) - set(df.describe()))
for col in categorical_cols:
  print(col ,':', df[col].unique())
# Out:
# hotel : ['Resort Hotel' 'City Hotel']
# meal : ['BB' 'FB' 'HB' 'SC' 'Undefined']
# deposit_type : ['No Deposit' 'Refundable' 'Non Refund']
# reserved_room_type : ['C' 'A' 'D' 'E' 'G' 'F' 'H' 'L' 'P' 'B']
# market_segment : ['Direct' 'Corporate' 'Online TA' 'Offline TA/TO' 'Complementary' 'Groups'
#  'Undefined' 'Aviation']
# reservation_status : ['Check-Out' 'Canceled' 'No-Show']
# assigned_room_type : ['C' 'A' 'D' 'E' 'G' 'F' 'I' 'B' 'H' 'P' 'L' 'K']
# distribution_channel : ['Direct' 'Corporate' 'TA/TO' 'Undefined' 'GDS']
# customer_type : ['Transient' 'Contract' 'Transient-Party' 'Group']

# %% [markdown]
# ##Distribution_channel : ['Direct' 'Corporate' 'TA/TO' 'Undefined' 'GDS']
# ##Hotel : ['Resort Hotel' 'City Hotel']
# ##Meal : ['BB' 'FB' 'HB' 'SC' 'Undefined']
# ##Reserved_room_type : ['C' 'A' 'D' 'E' 'G' 'F' 'H' 'L' 'P' 'B']
# ##Reservation_status : ['Check-Out' 'Canceled' 'No-Show']
# ##Deposit_type : ['No Deposit' 'Refundable' 'Non Refund']
# ##Customer_type : ['Transient' 'Contract' 'Transient-Party' 'Group']
# ##Assigned_room_type : ['C' 'A' 'D' 'E' 'G' 'F' 'I' 'B' 'H' 'P' 'L' 'K']
# ##Market_segment : ['Direct' 'Corporate' 'Online TA' 'Offline TA/TO' 'Complementary' 'Groups'
# ## 'Undefined' 'Aviation']

# %% [markdown]
# # Data Cleaning

# %%
# Finding duplicates True = duplicated value
df.duplicated().value_counts()
# Out:
# False    87396
# True     31994
# dtype: int64

# %%
# droping duplicates

df = df.drop_duplicates()

# %%
# Ensuring the column was dropped or not.

df.shape
# Out:
# (87396, 32)

# %%
# Finding null values

df.isnull().sum().sort_values(ascending = False)[:4]
# Out:
# company     82137
# agent       12193
# country       452
# children        4
# dtype: int64

# %%
# Dealing with null-values 
# 1. filling null values with 0 in company and agent column 
df[['company','agent']] = df[['company','agent']].fillna(0)

# 2. filling null values with others in country 
df['country'] = df['country'].fillna('others')

# 3. filling null values with mean of childrens
df['children'].fillna(df['children'].mean(), inplace = True)

# %%
# checking null value is replaced or not 

df.isnull().sum().sort_values(ascending = False) [:5]
# Out:
# hotel                          0
# is_canceled                    0
# reservation_status             0
# total_of_special_requests      0
# required_car_parking_spaces    0
# dtype: int64

# %%
# Changing Datatype of some columns

df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format = '%Y-%m-%d')

df[['children', 'company', 'agent']] = df[['children', 'company', 'agent']].astype('int64')

# %%
# Droping 166 rows containing children , adult, and babies is equal to zero because it makes no sense.

len(df[df['adults'] +df['children'] +df ['babies'] == 0])

df.drop(df[df['adults'] +df['children'] +df['babies'] == 0].index , inplace= True)

# %%
# Adding new column by combining some existing columns

df['total people']= df['adults'] +df['children'] +df ['babies']
df['total stayed'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']

# %%
df.head(1)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  company  \
# 0                        0                     0       2  ...        0
#
#    days_in_waiting_list customer_type  adr required_car_parking_spaces  \
# 0                     0     Transient  0.0                           0
#
#   total_of_special_requests  reservation_status  reservation_status_date  \
# 0                         0           Check-Out               2015-07-01
#
#    total people total stayed
# 0             2            0
#
# [1 rows x 34 columns]

# %%
# Checking correlation between meaningfull values in data frame

numeric_values = df[['previous_cancellations','previous_bookings_not_canceled','lead_time','booking_changes','days_in_waiting_list','adr','required_car_parking_spaces','total stayed','total people','total_of_special_requests']]
co_relation_matrix = numeric_values.corr()
f, ax = plt.subplots(figsize=(14,10))
sns.heatmap(co_relation_matrix, fmt='.2g',cmap= 'rocket_r',annot = True, annot_kws={'size': 12},  vmax = .9 )

# %% [markdown]
# ### <b> Observations from Correlation Matrix:
#
# * For longer duration of stays people generally plan little before the actual arrival.
# * Around 13% of total people have made a special request in their booking.
# * Barely any transaction have occurred which led to cancellation afterwards.

# %%
numeric_values = df[['previous_cancellations','previous_bookings_not_canceled','lead_time','booking_changes','days_in_waiting_list','adr','required_car_parking_spaces']]
plt.style.use('default')
plt.rcParams['figure.figsize'] = (10, 5)
numeric_values.boxplot()
plt.xticks(rotation=90,fontsize=15)
plt.yticks(fontsize=15)
# Out:
# (array([-1000.,     0.,  1000.,  2000.,  3000.,  4000.,  5000.,  6000.]),
#  <a list of 8 Text major ticklabel objects>)

# %% [markdown]
# **Here we see in column adr the value is beyond normal range so it indicates that value is a outlier.**

# %%
# Removing outliers

df.drop(df[df['adr'] > 5000].index, inplace = True)

# %% [markdown]
# ## <b> EDA [Exploratory Data Analysis]

# %% [markdown]
# ### <b> 1. Which Agent makes most no. of bookings

# %%
d1 = pd.DataFrame( df['agent'].value_counts()).reset_index().rename(columns = {'index':'agent','agent':'num_of_bookings'}).sort_values(by = 'num_of_bookings', ascending = False)
d1.drop(d1[d1['agent'] == 0].index, inplace = True)            # 0 represents that booking is not made by an agent
d1 = d1[:10]                                                   # Selecting top 10 performing agents
plt.figure(figsize = (10,5))
sns.barplot(x = 'agent', y = 'num_of_bookings', data = d1, order = d1.sort_values('num_of_bookings', ascending = False).agent)

# %% [markdown]
# ###inferances:
# Agent 9 made most of the booking

# %% [markdown]
# ### <b> 2. Hotel cancelation rate

# %%
# Selecting and counting number of cancelled bookings for each hotel.
cancelled_data = df[df['is_canceled'] == 1]
cancel_grp = cancelled_data.groupby('hotel')
D1 = pd.DataFrame(cancel_grp.size()).rename(columns = {0:'total_cancelled_bookings'})

# Counting total number of bookings for each type of hotel
grouped_by_hotel = df.groupby('hotel')
total_booking = grouped_by_hotel.size()
D2 = pd.DataFrame(total_booking).rename(columns = {0: 'total_bookings'})
D3 = pd.concat([D1,D2], axis = 1)

# Calculating cancel percentage 
D3['cancel_%'] = round((D3['total_cancelled_bookings']/D3['total_bookings'])*100,2)
D3
# Out:
#               total_cancelled_bookings  total_bookings  cancel_%
# hotel
# City Hotel                       16034           53273     30.10
# Resort Hotel                      7974           33956     23.48

# %% [markdown]
# ### <b> 3. Which Percentage of Booking changes made by the customer.

# %%
df.booking_changes.value_counts(normalize=True)
# Out:
# 0     0.818822
# 1     0.124580
# 2     0.039929
# 3     0.009882
# 4     0.003978
# 5     0.001295
# 6     0.000653
# 7     0.000332
# 8     0.000160
# 9     0.000092
# 10    0.000069
# 13    0.000057
# 14    0.000034
# 15    0.000034
# 17    0.000023
# 16    0.000023
# 12    0.000011
# 18    0.000011
# 11    0.000011
# Name: booking_changes, dtype: float64

# %% [markdown]
# ### <b> 4. From which country, guest visited the most.

# %% [markdown]
# * 0 no of customer 84% of booking change

# %%
plt.figure(figsize=(14,6))
grp_by_country =df.groupby('country')
d2 = pd.DataFrame(grp_by_country.size()).rename(columns = {0:'no. of bookings'}).sort_values('no. of bookings', ascending = False)
d2 = d2[:10]
sns.barplot(x = d2.index, y = d2['no. of bookings'])
plt.title('Most visited  Country')
plt.show()

# %% [markdown]
# ###Inferances:
# most of the guest are coming in portugal more than 40000

# %% [markdown]
# ### <b> 5.  Which year had the highest bookings?

# %%
# set plot size
plt.figure(figsize=(10,5))

#  plot with countplot
sns.countplot(x=df['arrival_date_year'],hue=df['hotel'], palette="magma")
plt.title("Year Wise bookings")
# Out:
# Text(0.5, 1.0, 'Year Wise bookings')

# %% [markdown]
# ###coclusion:
# 1.   2016 is the highest booking
# 2.   2015 iv very less booking

# %% [markdown]
# ### <b> 6. In which month most of the bookings happened?

# %%
# Grouping by
Booking_by_month = df.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns= {'hotel':'Counts', 'arrival_date_month': 'Months'})

# Month 
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# sorting dataframe by months
Booking_by_month['Months'] = pd.Categorical(Booking_by_month['Months'], categories = months, ordered = True )

sns.set_theme(style="darkgrid")
# plotting graph 
plt.figure(figsize = (20,8))
sns.lineplot(x = Booking_by_month['Months'],y = Booking_by_month['Counts'])
plt.title('Number of bookings month wise ', fontsize=25)
plt.xticks(fontsize=15,rotation=90)
plt.yticks(fontsize=15)
plt.ylabel('COUNTS',fontsize=18)
plt.xlabel('MONTHS',fontsize=18)
# Out:
# Text(0.5, 0, 'MONTHS')

# %% [markdown]
# # New Section

# %% [markdown]
# **Observation** :
#
# * July and August months had the most Bookings. Summer vaccation can be the reason for the bookings.

# %% [markdown]
# ### <b> 7. Most preferred room type by the customers

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = df['assigned_room_type'], order = df['assigned_room_type'].value_counts().index)
plt.ylabel('Count of Room Type')
plt.xlabel ('Room Types')
plt.title('Most prefered Room Types', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Most prefered Room Types')

# %% [markdown]
# **Observation** :
#
# * Most preferred Room type is 'A'.

# %% [markdown]
# ### <b> 8. count of repeated guest?

# %%
df['is_repeated_guest'].value_counts().plot.pie(explode=(0.06,0.09),startangle=180, shadow = True ,autopct='%1.1f%%',figsize=(12,8),fontsize=20)
plt.title('percent')
# Out:
# Text(0.5, 1.0, 'percent')

# %% [markdown]
# **Observation:**
#
# * Repeated guests are very few which only 3.9 %.
#
# * In order to retain the guests, management should take feedbacks from guests and try to improve the services.

# %% [markdown]
# ### <b> 9. Relationship between the repeated guests and previous bookings not canceled.?

# %%
rep_guests1 = df[df['is_repeated_guest']==1]
rep_guests0 = df[df['is_repeated_guest']==0]

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=df['is_repeated_guest'],y= df['previous_bookings_not_canceled'])
plt.xticks([0,1],['Not_repeated_guests','repeated_guests'],fontsize=15)
plt.title('Relationship Between repeated guests and previous bookings nor cancelled.', fontsize = 18)
plt.show()

# %% [markdown]
# **Observation** :
#
# * Not Repeated guests are more likely to cancel their bookings.

# %% [markdown]
# ### <b> 10. Which Hotel type has the highest ADR?

# %%
highest_ADR = pd.DataFrame(df.groupby(['hotel']) ['adr'].mean().reset_index())

# %%
highest_ADR
# Out:
#           hotel         adr
# 0    City Hotel  111.172693
# 1  Resort Hotel   99.059517

# %%
plt.figure(figsize= (10,5))
sns.barplot(x = highest_ADR['hotel'], y= highest_ADR['adr'])
plt.xlabel('Hotel type')
plt.ylabel ('ADR')
plt.title ('Avg ADR of hotel type')
# Out:
# Text(0.5, 1.0, 'Avg ADR of hotel type')

# %% [markdown]
# **Observation** :
#
# * City Hotel has the highest ADR. This means City Hotels are generating more revenue than the resort hotels. More the ADR, more is the revenue.

# %% [markdown]
# ### <b> 11. ADR across different  market segment

# %%
Grupby=df.groupby(['market_segment','hotel','is_canceled'])['adr'].mean().reset_index()   # group by

plt.figure(figsize=(18,6))
sns.barplot(x='market_segment',y='adr',hue='hotel',data=Grupby.sort_values(by='adr',ascending=False))
plt.title('Adr across market segment', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Adr across market segment')

# %% [markdown]
# **Obseravtion** :
#
# * 'Direct' and 'Online TA' are contributing the most in both types of hotels.
#
# * Aviation segment should focus on increasing the bookings of 'City Hotel'

# %% [markdown]
# **CONCLUSIONS**

# %% [markdown]
# 1.Agent no.9 makes most of the bookings.
#
# 2.27.5% of people cancelled their bookings. We have to find out the reasons why these people cancelled their bookings, & one thing also can be done to take feedback from them when they cancel their bookings.
#
# 3.Almost 82% of the bookings were not changed by guests.
#
# 4.Most of the guests are coming from portugal, i.e., more than 25,000 guests are from portugal.
#
# 5.July and August months had the most Bookings. Summer vaccation can be the reason for the bookings.
#
# 6.Repeated guests are very few which only 3.9 %.In order to retain the guests, management should take feedbacks from guests and try to improve the services.
#
# 7.City Hotel has the highest ADR. This means City Hotels are generating more revenue than the resort hotels. More the ADR, more is the revenue.
#
# 8.Not Repeated guests are more likely to cancel their bookings.
#
# 9.Direct' and 'Online TA' are contributing the most in both types of hotels.
#
# Aviation segment should focus on increasing the bookings of 'City Hotel'
